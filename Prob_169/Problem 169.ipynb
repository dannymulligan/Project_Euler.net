# %% [markdown]
# ![Project Euler.net](https://projecteuler.net/images/pe_banner_light.png)
#
# https://projecteuler.net/problem=169
# Problem 169 - Exploring the number of different ways a number can be expressed as a sum of powers of 2
# ====
#
# Define $f(0)=1$ and $f(n)$ to be the number of different ways $n$ can be expressed as a sum of integer powers of 2 using each power no more than twice.
#
# For example, $f(10)=5$ since there are five different ways to express $10$:
#
# $$1 + 1 + 8$$
# $$1 + 1 + 4 + 4$$
# $$1 + 1 + 2 + 2 + 4$$
# $$2 + 4 + 4$$
# $$2 + 8$$
#
# What is $f(10^{25})$?

# %% [markdown]
# ----
# Let's write a function that takes the size of the problem as a parameter, then verify it on $f(10)$, and probably a few bigger examples that we can check by hand.
#
# ----

# %% [markdown]
# So we will have to convert every number to binary, then try pushing digits to the right while verifying that no digit location is greater than 2.
#
# $10$ decimal is equivalent to $1010b$ in binary.
#
# $$1010b = 8 + 2$$
# $$1002b = 8 + 1 + 1$$
# $$0210b = 4 + 2$$
# $$0202b = 4 + 1 + 1$$
# $$0122b = 4 + 2 + 2 + 1 + 1$$
#
# So $f(10) = 5$

# %%
def Decimal2List(n):
    result = list()
    while n > 0:
        if (n % 2):
            n -= 1
            result = [1] + result
        else:
            result = [0] + result
        n /= 2
    if result == []:
        result = [0]
    return result

def List2Decimal(l):
    result = 0
    for n in l:
        result *= 2
        result += n
    return result

# %%
print("10 is {} in binary which is {} in decimal".format(Decimal2List(10), List2Decimal(Decimal2List(10))))
print("20 is {} in binary which is {} in decimal".format(Decimal2List(20), List2Decimal(Decimal2List(20))))
print("100 is {} in binary is {} in decimal".format(Decimal2List(100), List2Decimal(Decimal2List(100))))
print("10^25 is {} in binary which is {} in decimal".format(Decimal2List(10**25), List2Decimal(Decimal2List(10**25))))
print("(10^25 is {} digits long in binary)".format(len(Decimal2List(10**25))))

# %% [markdown]
# Let's calculate f(20) by hand.
#
# $20$ decimal is equivalent to $10100b$ in binary.
#
# $$10100b = 16 + 4$$
# $$10020b = 16 + 2 + 2$$
# $$10012b = 16 + 2 + 1 + 1$$
# $$02100b = 8 + 8 + 4$$
# $$02020b = 8 + 8 + 2 + 2$$
# $$02012b = 8 + 8 + 2 + 1 + 1$$
# $$01220b = 8 + 4 + 4 + 2 + 2$$
# $$01212b = 8 + 4 + 4 + 2 + 1 + 1$$
#
# So $f(20) = 8$
#
# Alternate way of calculating...
#
# $$f(10100b) = f(10b - 00b) * f(000b + 100b) + f(10b - 01b) * f(200b + 100b)$$
#
# $f(10b - 02b) * f(400b + 100b)$ is not possible, because $400b$ can never satisify the rules
#
# ----
#
# So let's calculate $f(100) = f(1100100b)$ by hand.
#
# $$f(1100100b) = f(110b) * f(0100b) + f(110b - 001b) * f(2000b + 0100b)$$
# $$\quad \quad \quad \quad \quad = f(110b) * f(0100b) + f(101b) * f(2100b)$$
#
# $$f(110b) = 3$$
# $$\quad 110b$$
# $$\quad 102b$$
# $$\quad 022b$$
#
# $$f(101b) = 2$$
# $$\quad 101b$$
# $$\quad 021b$$
#
# $$f(0100b) = 3$$
# $$\quad 0100b$$
# $$\quad 0020b$$
# $$\quad 0012b$$
#
# $$f(2100b) = 5$$
# $$\quad 2100b$$
# $$\quad 2020b$$
# $$\quad 2012b$$
# $$\quad 1220b$$
# $$\quad 1212b$$
#
# $$f(1100100b) = f(110b) * f(0100b) + f(101b) * f(2100b)$$
# $$\quad \quad \quad \quad \quad = 3 * 3 + 2 * 5 = 9 + 10 = 19$$
#
# $$\quad 1100100b$$
# $$\quad 1100020b$$
# $$\quad 1100012b$$
#
# $$\quad 1020100b$$
# $$\quad 1020020b$$
# $$\quad 1020012b$$
#
# $$\quad 0220100b$$
# $$\quad 0220020b$$
# $$\quad 0220012b$$
#
# $$\quad 1012100b$$
# $$\quad 1012020b$$
# $$\quad 1012012b$$
# $$\quad 1011220b$$
# $$\quad 1011212b$$
#
# $$\quad 0212100b$$
# $$\quad 0212020b$$
# $$\quad 0212012b$$
# $$\quad 0211220b$$
# $$\quad 0211212b$$

# %%
print(List2Decimal([1, 1, 0, 0, 1, 0, 0]))
print(List2Decimal([1, 1, 0, 0, 0, 2, 0]))
print(List2Decimal([1, 1, 0, 0, 0, 1, 2]))

print(List2Decimal([1, 0, 2, 0, 1, 0, 0]))
print(List2Decimal([1, 0, 2, 0, 0, 2, 0]))
print(List2Decimal([1, 0, 2, 0, 0, 1, 2]))

print(List2Decimal([0, 2, 2, 0, 1, 0, 0]))
print(List2Decimal([0, 2, 2, 0, 0, 2, 0]))
print(List2Decimal([0, 2, 2, 0, 0, 1, 2]))

print(List2Decimal([1, 0, 1, 2, 1, 0, 0]))
print(List2Decimal([1, 0, 1, 2, 0, 2, 0]))
print(List2Decimal([1, 0, 1, 2, 0, 1, 2]))
print(List2Decimal([1, 0, 1, 1, 2, 2, 0]))
print(List2Decimal([1, 0, 1, 1, 2, 1, 2]))

print(List2Decimal([0, 2, 1, 2, 1, 0, 0]))
print(List2Decimal([0, 2, 1, 2, 0, 2, 0]))
print(List2Decimal([0, 2, 1, 2, 0, 1, 2]))
print(List2Decimal([0, 2, 1, 1, 2, 2, 0]))
print(List2Decimal([0, 2, 1, 1, 2, 1, 2]))

# %%
def f(n):
    print("Calling f({})".format(n))
    ln = Decimal2List(n)
    return fl(ln)

# %%
print("SubR([0, 0]) = {}".format(SubR([0, 0])))
print("SubR([0, 1]) = {}".format(SubR([0, 1])))
print("SubR([0, 2]) = {}".format(SubR([0, 2])))
print("SubR([1, 0]) = {}".format(SubR([1, 0])))
print("SubR([1, 1]) = {}".format(SubR([1, 1])))
print("SubR([1, 2]) = {}".format(SubR([1, 2])))
print("SubR([2, 0]) = {}".format(SubR([2, 0])))
print("SubR([2, 1]) = {}".format(SubR([2, 1])))
print("SubR([2, 2]) = {}".format(SubR([2, 2])))
print("")
print("SubR([0, 0, 0]) = {}".format(SubR([0, 0, 0])))
print("SubR([0, 0, 1]) = {}".format(SubR([0, 0, 1])))
print("SubR([0, 0, 2]) = {}".format(SubR([0, 0, 2])))
print("SubR([0, 1, 0]) = {}".format(SubR([0, 1, 0])))
print("SubR([0, 1, 1]) = {}".format(SubR([0, 1, 1])))
print("SubR([0, 1, 2]) = {}".format(SubR([0, 1, 2])))
print("SubR([0, 2, 0]) = {}".format(SubR([0, 2, 0])))
print("SubR([0, 2, 1]) = {}".format(SubR([0, 2, 1])))
print("SubR([0, 2, 2]) = {}".format(SubR([0, 2, 2])))
print("SubR([1, 0, 0]) = {}".format(SubR([1, 0, 0])))
print("SubR([1, 0, 1]) = {}".format(SubR([1, 0, 1])))
print("SubR([1, 0, 2]) = {}".format(SubR([1, 0, 2])))
print("SubR([1, 1, 0]) = {}".format(SubR([1, 1, 0])))
print("SubR([1, 1, 1]) = {}".format(SubR([1, 1, 1])))
print("SubR([1, 1, 2]) = {}".format(SubR([1, 1, 2])))
print("SubR([2, 1, 0]) = {}".format(SubR([2, 1, 0])))
print("SubR([2, 1, 1]) = {}".format(SubR([2, 1, 1])))
print("SubR([2, 1, 2]) = {}".format(SubR([2, 1, 2])))

# %%
def AddL(l):
    # Add 20..0b to l
    if l[0] == 2:
        return [-1], l[1:]
    
    l[0] += 2
    carry = 0
    for i in len(l):
        l[i] += carry
        if l[i] > 2:
            carry = (l[i] - 2)*2
    if carry != 0:
        return [-1], l[1:]
    return l

# %%
print("SubR([0, 0, 0]) = {}".format(SubR([0, 0, 0])))
print("SubR([0, 0, 1]) = {}".format(SubR([0, 0, 1])))
print("SubR([0, 1, 0]) = {}".format(SubR([0, 1, 0])))
print("SubR([0, 1, 1]) = {}".format(SubR([0, 1, 1])))
print("SubR([1, 0, 0]) = {}".format(SubR([1, 0, 0])))
print("SubR([1, 0, 1]) = {}".format(SubR([1, 0, 1])))
print("SubR([1, 1, 0]) = {}".format(SubR([1, 1, 0])))
print("SubR([1, 1, 1]) = {}".format(SubR([1, 1, 1])))

# %%
def fl(ln):
    #print("Calling fl({})".format(ln))
    if len(ln) <= 2:
        if   ln ==    [0]:  return 1
        elif ln ==    [1]:  return 1
        elif ln ==    [2]:  return 1
        elif ln == [0, 0]:  return 1
        elif ln == [0, 1]:  return 1
        elif ln == [0, 2]:  return 1
        elif ln == [1, 0]:  return 2  # [1, 0] & [0, 2]
        elif ln == [1, 1]:  return 1
        elif ln == [1, 2]:  return 1
        elif ln == [2, 0]:  return 2  # [2, 0] & [1, 2]
        elif ln == [2, 1]:  return 1
        elif ln == [2, 2]:  return 1
        elif ln == [3, 0]:  return 1  # [2, 2]
        else:              return 0
    else:
        # Split the list in half
        la, ra = ln[:len(ln)/2], ln[len(ln)/2:]
        #print("Splitting the list {} into {} & {}".format(ln, la, ra))
        
        # Calculate f(left) * f(right) + f(left - 0..01b) * f(right + 20..0b)
        fl_la = fl(la)
        
        fl_ra = fl(ra)
        
        lb = SubR(la)
        if (lb[-1] == -1):
            fl_lb = 0
        else:
            fl_lb = fl(lb)
            
        rb = [ra[0] + 2] + ra[1:]
        fl_rb = fl(rb)
        print("    fl({}) = fl({})*fl({}) + fl({})*fl({}) = {}*{} + {}*{} = {}".format(
            ln, la, ra, lb, rb, fl_la, fl_ra, fl_lb, fl_rb, fl_la*fl_ra + fl_lb*fl_rb))
        return fl_la*fl_ra + fl_lb*fl_rb

# %%
f(10)

# %%
f(20)

# %%
f(100)

# %%
f(1000)

# %%
f(10**25)
